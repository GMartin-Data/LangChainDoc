# %% [markdown]
# # LangChain Expression Language (LCEL)

# %% [markdown]
# Based on [**this tutorial**](https://learn.deeplearning.ai/courses/functions-tools-agents-langchain/lesson/3/langchain-expression-language-(lcel))

# %% [markdown]
# # Foreword

# %% [markdown]
# This is a new syntax that makes it more straightforward and transparent to work with chains.

# %% [markdown]
# ## Principles

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interface

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Why Use LCEL?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Setup

# %%
from dotenv import load_dotenv

# %%
_ = load_dotenv()

# %% [markdown]
# # Global Imports

# %% [markdown]
# > **NOTE**
# >
# > Imports have been updated from the tutorial ones.

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai.chat_models import ChatOpenAI

# %% [markdown]
# # Simple Chain
