# %% [markdown]
# # Resources

# %% [markdown]
# - [**Alejandro AO's Video**](https://www.youtube.com/watch?v=dXxQ0LR-3Hg)
# - [**DeepLearningAI Course - Chat With Your Data**](https://learn.deeplearning.ai/courses/langchain-chat-with-your-data/lesson/1/introduction)
# - [**Focused Labs' Video**](https://www.youtube.com/watch?v=UwgZmrRAgQ4): A lot more technical but quite interesting!

# %% [markdown]
# # Setup

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Implement a RAG to Chat With a PDF

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# For this to work, you also need to have installed `pypdf` (added to requirements)

# %%
loader = PyPDFLoader("docs/instruction_tuning_cropped.pdf")

# %%
pages = loader.load()

# %%
type(pages), len(pages)
# Out:
# (list, 16)

# %%
page = pages[0]
len(page.page_content)
# Out:
# 2899

# %%
print(page.page_content[:500])
# Out:
# Instruction Tuning With Loss Over Instructions
# Zhengyan Shi1Adam X. Yang2Bin Wu1
# Laurence Aitchison2Emine Yilmaz1Aldo Lipani1
# 1University College London2University of Bristol
# {zhengxiang.shi.19,bin.wu.23,aldo.lipani,emine.yilmaz}@ucl.ac.uk
# {adam.yang,laurence.aitchison}@bristol.ac.uk
# Abstract
# Instruction tuning plays a crucial role in shaping the outputs of language models
# (LMs) to desired styles. In this work, we propose a simple yet effective method,
# INSTRUCTION MODELLING (IM), which trains LM

# %%
page.metadata
# Out:
# {'source': 'docs/instruction_tuning_cropped.pdf', 'page': 0}
